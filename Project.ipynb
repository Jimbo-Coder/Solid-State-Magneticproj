# %%
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division
import scipy
import pandas as pd
import random as rand

theta =0
M = 1
accuracy = 0.001
bt = np.arange(-1,1,accuracy);
ht = 3*M*bt
phis=[]
m=[0.1,1.,2.,3.,4.,5.,6.];
#m = [0.,3.]
phist = [];
randos =300; thetas = np.array([0,18,30,34,60,90])*np.pi/180;
thetas = np.array([90])*np.pi/180;
for p in range(randos):
    theta = rand.uniform(0,np.pi)
    #theta = thetas[p]
    phis=[]
    for j in np.arange(-1, 1, accuracy):

        b= j
        def func(x):
            return(0.5*np.sin(2*(x - theta) + b*np.sin(x)))

        b0 =0
        min = 0
        max = 2*np.pi # set max to some sufficiently large value
        k=[]; n = 0;
        while n<7:
            y=0;x=m[n]
            f=0.5*np.sin(2*x - 2*theta) + b*np.sin(x)
            while abs(f)>1e-8:
                f=0.5*np.sin(2*x - 2*theta) + b*np.sin(x)
                df=np.cos(2*x - 2*theta) + b*np.cos(x)
                xi=x-(f/df)
                x=xi
                y+=1
                while x < 0:
                    x = x + 2*np.pi
                while x > 2*np.pi:
                    x = x - 2*np.pi
                if y > 1000:
                    x = 999
                    break
            k.append(x)
            n+=1

        phis.append(k)
    phist.append(phis)

# %%
phit=[]; phistt = []
for k in range(randos):
    phis = phist[k]; phit=[]
    for j in range(n):
        t=[];
        for i in phis:
            t.append(i[j])
        phit.append(np.array(t))
    phistt.append(phit)
        
phit

lt = len(phis);l = int(len(bt));
plt.figure()
plt.title("300 nanomagnets, random θ's")
plt.axhline([0]);plt.axvline([0]);
plt.xlabel("H");
plt.ylabel("m"); colors = ['b','g','r','c','m','y','k']
for k in range(randos):
    phit1 = phistt[k]
    for i in range(n):
        mt = M*np.cos(phit1[i])
        plt.scatter(bt, mt,s=.0001, c = colors[6])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 4
#       2 thetas = np.array(thetas[1]);
#       3 thetas
# ----> 4 len(thetas)
#
# TypeError: len() of unsized object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[253], line 4
#       2 m1 = M*np.cos(xt[0:l2])
#       3 plt.figure()
# ----> 4 plt.scatter(m1, bs1,s = 3)
#       5 plt.scatter(m1, bs2, s= 3)
#
# File ~\venv4\Lib\site-packages\matplotlib\pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
#    2836         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2837         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2838         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2839         **({"data": data} if data is not None else {}), **kwargs)
#    2840     sci(__ret)
#    2841     return __ret
#
# File ~\venv4\Lib\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\venv4\Lib\site-packages\matplotlib\axes\_axes.py:4584, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4582 y = np.ma.ravel(y)
#    4583 if x.size != y.size:
# -> 4584     raise ValueError("x and y must be the same size")
#    4586 if s is None:
#    4587     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4588          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
